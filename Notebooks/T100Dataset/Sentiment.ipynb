# %%
# Load all the reviews into a single df
import os
import pandas as pd

# Initialize empty list to store dataframes
dfs = []

# Walk through the RMPT100Reviews/combined directory
for root, dirs, files in os.walk('../../RMPT100Reviews/universities'):
    for file in files:
        if file == 'reviews.csv':
            # Construct full file path
            file_path = os.path.join(root, file)
            # Read CSV and append to list
            df = pd.read_csv(file_path)
            dfs.append(df)

# Concatenate all dataframes
df = pd.concat(dfs, ignore_index=True)

# Format numbers to avoid scientific notation
pd.set_option('display.float_format', lambda x: '%.3f' % x)
display(df.describe())
# Out:
#             index  clarity_rating  difficulty_rating  helpful_rating  \
# count 3396084.000     3396084.000        3396084.000     3396084.000
# mean    27498.122           3.644              3.052           3.668
# std     21383.378           1.500              1.222           1.517
# min         0.000           1.000              1.000          -1.000
# 25%     10019.000           2.000              2.000           2.000
# 50%     22674.000           4.000              3.000           4.000
# 75%     40959.000           5.000              4.000           5.000
# max    107192.000           5.000              5.000           5.000
#
#        quality_rating  textbook_use  thumbs_down_total  thumbs_up_total  \
# count     3396084.000   2962539.000        3396084.000      3396084.000
# mean            3.734         2.402              0.335            0.593
# std             1.480         2.193              2.476            8.208
# ...

# %%
#Get the distribution of all the sentiments
from textblob import TextBlob
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# Let's do a little example with the first review
review = df.iloc[0]
print(review['comment'])

# Let's get the 'TextBlob' of the review
wiki = TextBlob(review['comment'])
print(wiki.noun_phrases)

# Let's get the sentiment of the review
sentiment = wiki.sentiment
print(sentiment) 
# This is a tuple with the polarity and subjectivity
# Polarity is a float between -1 and 1, with 1 indicating a very positive sentiment and -1 indicating a very negative sentiment
# Subjectivity is a float between 0 and 1, with 0 indicating a very objective sentiment and 1 indicating a very subjective sentiment

# Handle NaN values and convert to string before applying TextBlob
# Process both polarity and subjectivity in a single TextBlob call
polarities = []
subjectivities = []

print("Processing sentiment analysis...")
for comment in tqdm(df['comment']):
    if pd.notna(comment):
        blob = TextBlob(str(comment))
        polarities.append(blob.sentiment.polarity)
        subjectivities.append(blob.sentiment.subjectivity)
    else:
        polarities.append(0)
        subjectivities.append(0)

df['polarity'] = polarities
df['subjectivity'] = subjectivities

# Create a figure with two subplots
plt.figure(figsize=(12, 8))

# Plot polarity distribution
plt.subplot(2, 1, 1)
plt.hist(df['polarity'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Polarity')
plt.xlabel('Polarity (-1: Negative, 1: Positive)')
plt.ylabel('Frequency')
plt.grid(alpha=0.3)

# Plot subjectivity distribution
plt.subplot(2, 1, 2)
plt.hist(df['subjectivity'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of Sentiment Subjectivity')
plt.xlabel('Subjectivity (0: Objective, 1: Subjective)')
plt.ylabel('Frequency')
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# Calculate and display average sentiment metrics
avg_polarity = df['polarity'].mean()
avg_subjectivity = df['subjectivity'].mean()
print(f"Average Polarity: {avg_polarity:.4f} (-1: Negative, 1: Positive)")
print(f"Average Subjectivity: {avg_subjectivity:.4f} (0: Objective, 1: Subjective)")
# Out:
# This class is lecture heavy so get ready to write/type/record. The book is used some but the majority of his test questions come from lecture material
# ['test questions', 'lecture material']
# Sentiment(polarity=0.0, subjectivity=0.5)
# Processing sentiment analysis...
# 100%|██████████| 3396084/3396084 [26:46<00:00, 2114.61it/s]
# Average Polarity: 0.1737 (-1: Negative, 1: Positive)
# Average Subjectivity: 0.5718 (0: Objective, 1: Subjective)

# %%
# Map polarity to a normal distribution
from scipy import stats
import numpy as np

# First, let's check the current distribution of polarity
print("Original polarity statistics:")
print(df['polarity'].describe())

# Create a new column with normalized polarity values
# Using the Probability Integral Transform to map to a normal distribution
# First, get the empirical CDF of the data
ecdf = stats.rankdata(df['polarity']) / len(df['polarity'])

# Then, apply the inverse normal CDF to get normally distributed values
df['normalized_polarity'] = stats.norm.ppf(ecdf)

# Replace any infinite values that might occur at the extremes
df['normalized_polarity'].replace([np.inf, -np.inf], [3, -3], inplace=True)

# Display statistics of the normalized distribution
print("\nNormalized polarity statistics:")
print(df['normalized_polarity'].describe())

# Plot the original vs normalized distributions
plt.figure(figsize=(14, 6))

# Original distribution
plt.subplot(1, 2, 1)
plt.hist(df['polarity'], bins=30, color='skyblue', edgecolor='black')
plt.title('Original Polarity Distribution')
plt.xlabel('Polarity')
plt.ylabel('Frequency')
plt.grid(alpha=0.3)

# Normalized distribution
plt.subplot(1, 2, 2)
plt.hist(df['normalized_polarity'], bins=30, color='lightgreen', edgecolor='black')
plt.title('Normalized Polarity Distribution')
plt.xlabel('Normalized Polarity')
plt.ylabel('Frequency')
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Original polarity statistics:
# count   3396084.000
# mean          0.174
# std           0.279
# min          -1.000
# 25%           0.002
# 50%           0.190
# 75%           0.342
# max           1.000
# Name: polarity, dtype: float64
# C:\Users\austi\AppData\Local\Temp\ipykernel_20360\2106310744.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['normalized_polarity'].replace([np.inf, -np.inf], [3, -3], inplace=True)
# Normalized polarity statistics:
# count   3396084.000
# mean         -0.000
# ...

# %%
# Save the parameters of the normalization for future use
# This will allow us to apply the same transformation to new data
import json
import pickle
import os

# Calculate the mean and standard deviation of the normalized distribution
norm_mean = df['normalized_polarity'].mean()
norm_std = df['normalized_polarity'].std()

# Save the original polarity min, max, and quantiles for reference
polarity_min = df['polarity'].min()
polarity_max = df['polarity'].max()
polarity_quantiles = df['polarity'].quantile([0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.99])

# Create a function to normalize new polarity values using the same distribution
def normalize_polarity(new_polarity_values):
    """
    Normalize new polarity values using the same distribution as the training data.
    
    Args:
        new_polarity_values: Array-like object containing polarity scores to normalize
        
    Returns:
        Array of normalized polarity values
    """
    # Get the empirical CDF ranks for the new values relative to the original distribution
    # We use the original df['polarity'] as the reference distribution
    combined = np.concatenate([df['polarity'].values, np.array(new_polarity_values)])
    ranks = stats.rankdata(combined)
    
    # Extract only the ranks for the new values (they're at the end of the array)
    new_ranks = ranks[len(df['polarity']):]
    
    # Convert ranks to percentiles
    percentiles = (new_ranks - 0.5) / len(combined)
    
    # Apply inverse normal CDF
    normalized_values = stats.norm.ppf(percentiles)
    
    # Replace any infinite values
    normalized_values = np.clip(normalized_values, -3, 3)
    
    return normalized_values

# Save normalization parameters to a dictionary for easy access
normalization_params = {
    'original_mean': float(df['polarity'].mean()),
    'original_std': float(df['polarity'].std()),
    'normalized_mean': float(norm_mean),
    'normalized_std': float(norm_std),
    'polarity_min': float(polarity_min),
    'polarity_max': float(polarity_max),
    'polarity_quantiles': {str(k): float(v) for k, v in polarity_quantiles.to_dict().items()}
}

# Create output directory if it doesn't exist
output_dir = 'normalization_data'
os.makedirs(output_dir, exist_ok=True)

# Save parameters as JSON for human-readable format
json_path = os.path.join(output_dir, 'polarity_normalization_params.json')
with open(json_path, 'w') as f:
    json.dump(normalization_params, f, indent=4)

# Save the entire normalization context (including the original polarity values) for more accurate transformations
normalization_context = {
    'params': normalization_params,
    'original_polarity_values': df['polarity'].values.tolist()
}

# Save as pickle for programmatic use with the full distribution data
pickle_path = os.path.join(output_dir, 'polarity_normalization_context.pkl')
with open(pickle_path, 'wb') as f:
    pickle.dump(normalization_context, f)

print(f"Normalization parameters saved to {json_path}")
print(f"Full normalization context saved to {pickle_path}")
print("Use the normalize_polarity() function to transform new data.")
print(f"Normalization parameters: {normalization_params}")
# Out:
# Normalization parameters saved to normalization_data\polarity_normalization_params.json
# Full normalization context saved to normalization_data\polarity_normalization_context.pkl
# Use the normalize_polarity() function to transform new data.
# Normalization parameters: {'original_mean': 0.17367111985615713, 'original_std': 0.27919562061398756, 'normalized_mean': -0.0004245127633839519, 'normalized_std': 0.9955001068123789, 'polarity_min': -1.0, 'polarity_max': 1.0, 'polarity_quantiles': {'0.01': -0.65, '0.05': -0.2899999999999999, '0.25': 0.002083333333333326, '0.5': 0.19, '0.75': 0.3416666666666666, '0.95': 0.5958333333333333, '0.99': 1.0}}
